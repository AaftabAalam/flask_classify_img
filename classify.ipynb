# %%
import tensorflow as tf

# %%
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input,decode_predictions

# %%
import matplotlib.pyplot as mplt

# %%
from tensorflow.keras.preprocessing import image

# %%
import numpy as np

# %%
model = VGG16(weights='imagenet')
model
# Out:
# 2024-06-22 08:55:19.337915: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2024-06-22 08:55:19.337941: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-06-22 08:55:19.337950: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-06-22 08:55:19.337993: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-06-22 08:55:19.338016: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
def load_and_preprocess(img_path):
    img = image.load_img(img_path,target_size=(224,224))
    img_arr = image.img_to_array(img)
    img_arr = np.expand_dims(img_arr,axis=0)
    img_arr = preprocess_input(img_arr)
    return img_arr

# %%
def predictions(model,img_path):
    img = image.load_img(img_path)
    img_arr = image.img_to_array(img)
    mplt.imshow(img_arr/255.0)
    img_arr = load_and_preprocess(img_path)
    preds = model.predict(img_arr)
    decodes_preds = decode_predictions(preds,top=3)
    for id,name,score in decodes_preds[0]:
        print(f'{name}:{score*100:.2f}')

# %%
import joblib

# %%
model = joblib.load('vgg16.joblib')
model
# Out:
# 2024-06-23 08:48:23.442284: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2024-06-23 08:48:23.442309: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-06-23 08:48:23.442316: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-06-23 08:48:23.443026: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-06-23 08:48:23.443363: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
predictions(model,'/Users/apple/Downloads/100_0274-min.jpg')
# Out:
# 1/1 [==============================] - 0s 283ms/step
# 2024-06-23 08:48:27.105304: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# folding_chair:99.88
# rocking_chair:0.12
# drum:0.00

# %%
predictions(model,'/Users/apple/Downloads/images.jpeg')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 predictions(model,'/Users/apple/Downloads/images.jpeg')
#
# Cell In[7], line 2, in predictions(model, img_path)
#       1 def predictions(model,img_path):
# ----> 2     img = image.load_img(img_path)
#       3     img_arr = image.img_to_array(img)
#       4     mplt.imshow(img_arr/255.0)
#
# File ~/ml-setup/env/lib/python3.8/site-packages/keras/src/utils/image_utils.py:422, in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     420     if isinstance(path, pathlib.Path):
#     421         path = str(path.resolve())
# --> 422     with open(path, "rb") as f:
#     423         img = pil_image.open(io.BytesIO(f.read()))
#     424 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/apple/Downloads/images.jpeg'

# %%
predictions(model,'/Users/apple/Downloads/nLDqFXpa6q4UHVgWoEg2de-1200-80.jpg')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 predictions(model,'/Users/apple/Downloads/nLDqFXpa6q4UHVgWoEg2de-1200-80.jpg')
#
# Cell In[7], line 2, in predictions(model, img_path)
#       1 def predictions(model,img_path):
# ----> 2     img = image.load_img(img_path)
#       3     img_arr = image.img_to_array(img)
#       4     mplt.imshow(img_arr/255.0)
#
# File ~/ml-setup/env/lib/python3.8/site-packages/keras/src/utils/image_utils.py:422, in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     420     if isinstance(path, pathlib.Path):
#     421         path = str(path.resolve())
# --> 422     with open(path, "rb") as f:
#     423         img = pil_image.open(io.BytesIO(f.read()))
#     424 else:
#
# ...

# %%
predictions(model,'/Users/apple/Downloads/SStringray.jpg')
# Out:
# 1/1 [==============================] - 0s 31ms/step
# stingray:100.00
# electric_ray:0.00
# shovel:0.00

# %%
predictions(model,'/Users/apple/Downloads/7grkegytV4qrcMb9zSQT8V.jpg')
# Out:
# 1/1 [==============================] - 0s 25ms/step
# Indian_cobra:75.25
# frilled_lizard:15.22
# night_snake:9.53

# %%
predictions(model,'/Users/apple/Downloads/images-3.jpeg')
# Out:
# 1/1 [==============================] - 0s 29ms/step
# loggerhead:100.00
# conch:0.00
# starfish:0.00

# %%
predictions(model,'/Users/apple/Downloads/images-4.jpeg')
# Out:
# 1/1 [==============================] - 0s 24ms/step
# loggerhead:100.00
# terrapin:0.00
# toilet_tissue:0.00

# %%
predictions(model,'/Users/apple/Downloads/Wolf_spider_-__Allocosa_obscuroides.width-1200.3915b07.jpg')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 predictions(model,'/Users/apple/Downloads/Wolf_spider_-__Allocosa_obscuroides.width-1200.3915b07.jpg')
#
# Cell In[7], line 2, in predictions(model, img_path)
#       1 def predictions(model,img_path):
# ----> 2     img = image.load_img(img_path)
#       3     img_arr = image.img_to_array(img)
#       4     mplt.imshow(img_arr/255.0)
#
# File ~/ml-setup/env/lib/python3.8/site-packages/keras/src/utils/image_utils.py:422, in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     420     if isinstance(path, pathlib.Path):
#     421         path = str(path.resolve())
# --> 422     with open(path, "rb") as f:
#     423         img = pil_image.open(io.BytesIO(f.read()))
#     424 else:
#
# ...

# %%
predictions(model,'/Users/apple/Downloads/best-beaches-in-the-world.jpg')
# Out:
# 1/1 [==============================] - 0s 56ms/step
# seashore:100.00
# lakeside:0.00
# sandbar:0.00

# %%
predictions(model,'/Users/apple/Downloads/plage.jpg')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 predictions(model,'/Users/apple/Downloads/plage.jpg')
#
# Cell In[7], line 2, in predictions(model, img_path)
#       1 def predictions(model,img_path):
# ----> 2     img = image.load_img(img_path)
#       3     img_arr = image.img_to_array(img)
#       4     mplt.imshow(img_arr/255.0)
#
# File ~/ml-setup/env/lib/python3.8/site-packages/keras/src/utils/image_utils.py:422, in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     420     if isinstance(path, pathlib.Path):
#     421         path = str(path.resolve())
# --> 422     with open(path, "rb") as f:
#     423         img = pil_image.open(io.BytesIO(f.read()))
#     424 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/apple/Downloads/plage.jpg'

# %%
predictions(model,'/Users/apple/Downloads/Luftbildaufnahme_Makena_Big_Beach,_Maui_Hawaii_(45740086501).jpg')
# Out:
# 1/1 [==============================] - 0s 32ms/step
# seashore:100.00
# sandbar:0.00
# lakeside:0.00

# %%
predictions(model,'/Users/apple/Downloads/220_2048x2048.png.webp')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 predictions(model,'/Users/apple/Downloads/220_2048x2048.png.webp')
#
# Cell In[7], line 2, in predictions(model, img_path)
#       1 def predictions(model,img_path):
# ----> 2     img = image.load_img(img_path)
#       3     img_arr = image.img_to_array(img)
#       4     mplt.imshow(img_arr/255.0)
#
# File ~/ml-setup/env/lib/python3.8/site-packages/keras/src/utils/image_utils.py:422, in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     420     if isinstance(path, pathlib.Path):
#     421         path = str(path.resolve())
# --> 422     with open(path, "rb") as f:
#     423         img = pil_image.open(io.BytesIO(f.read()))
#     424 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/apple/Downloads/220_2048x2048.png.webp'

# %%
import joblib

# %%
joblib.dump(model,'vgg16.joblib')
# Out:
# ['vgg16.joblib']

# %%
vgg = joblib.load('vgg16.joblib')
vgg
# Out:
# 2024-06-22 17:55:26.368336: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2024-06-22 17:55:26.368361: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-06-22 17:55:26.368368: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-06-22 17:55:26.368446: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-06-22 17:55:26.368664: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
predictions(model,'/Users/apple/Downloads/test images/220_2048x2048.png.webp')
# Out:
# 1/1 [==============================] - 0s 18ms/step
# hammer:100.00
# hatchet:0.00
# spatula:0.00

# %%
predictions(model,'/Users/apple/Downloads/test images/images.jpeg')
# Out:
# 1/1 [==============================] - 0s 24ms/step
# bald_eagle:100.00
# vulture:0.00
# kite:0.00

# %% [markdown]
# ## Streamlit test in ipynb

# %%
import requests

# %%
labels_url = 'https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json'

# %%
response = requests.get(labels_url)
class_labels = response.json()
class_labels
# Out:
# {'0': ['n01440764', 'tench'],
#  '1': ['n01443537', 'goldfish'],
#  '2': ['n01484850', 'great_white_shark'],
#  '3': ['n01491361', 'tiger_shark'],
#  '4': ['n01494475', 'hammerhead'],
#  '5': ['n01496331', 'electric_ray'],
#  '6': ['n01498041', 'stingray'],
#  '7': ['n01514668', 'cock'],
#  '8': ['n01514859', 'hen'],
#  '9': ['n01518878', 'ostrich'],
#  '10': ['n01530575', 'brambling'],
#  '11': ['n01531178', 'goldfinch'],
#  '12': ['n01532829', 'house_finch'],
#  '13': ['n01534433', 'junco'],
#  '14': ['n01537544', 'indigo_bunting'],
#  '15': ['n01558993', 'robin'],
#  '16': ['n01560419', 'bulbul'],
#  '17': ['n01580077', 'jay'],
#  '18': ['n01582220', 'magpie'],
#  '19': ['n01592084', 'chickadee'],
#  '20': ['n01601694', 'water_ouzel'],
#  '21': ['n01608432', 'kite'],
#  '22': ['n01614925', 'bald_eagle'],
#  '23': ['n01616318', 'vulture'],
#  '24': ['n01622779', 'great_grey_owl'],
#  '25': ['n01629819', 'European_fire_salamander'],
#  '26': ['n01630670', 'common_newt'],
# ...

# %%
class_labels = [class_labels[str(i)][1] for i in range(len(class_labels))]
class_labels
# Out:
# ['tench',
#  'goldfish',
#  'great_white_shark',
#  'tiger_shark',
#  'hammerhead',
#  'electric_ray',
#  'stingray',
#  'cock',
#  'hen',
#  'ostrich',
#  'brambling',
#  'goldfinch',
#  'house_finch',
#  'junco',
#  'indigo_bunting',
#  'robin',
#  'bulbul',
#  'jay',
#  'magpie',
#  'chickadee',
#  'water_ouzel',
#  'kite',
#  'bald_eagle',
#  'vulture',
#  'great_grey_owl',
#  'European_fire_salamander',
#  'common_newt',
#  'eft',
#  'spotted_salamander',
#  'axolotl',
#  'bullfrog',
#  'tree_frog',
#  'tailed_frog',
#  'loggerhead',
#  'leatherback_turtle',
#  'mud_turtle',
#  'terrapin',
#  'box_turtle',
#  'banded_gecko',
#  'common_iguana',
#  'American_chameleon',
#  'whiptail',
#  'agama',
#  'frilled_lizard',
#  'alligator_lizard',
#  'Gila_monster',
#  'green_lizard',
#  'African_chameleon',
#  'Komodo_dragon',
#  'African_crocodile',
#  'American_alligator',
#  'triceratops',
#  'thunder_snake',
#  'ringneck_snake',
#  'hognose_snake',
#  'green_snake',
# ...

# %%
def preprocess_image(image):
    resized = image.resize(224,224)
    img_arr = img_to_array(resized)
    batch_no = np.expand_dims(img_arr,axis=0)
    img_arr = preprocess_input(batch_no)
    return img_arr

# %%
import streamlit as sl

# %%
sl.file_uploader('Upload your file')
